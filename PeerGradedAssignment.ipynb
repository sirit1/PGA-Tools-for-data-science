# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Bethany Thomas**
# Data Scientist

# %% [markdown]
# *I am interested in data science because I enjoy collecting, analyzing and presenting data based on empiracal evidence.*

# %% [markdown]
# ### In Cell 5, I am going to input a code to perform a simple mathematics equation.

# %%
5 + 7
# Out:
# 12

# %% [markdown]
# # Here is a horizontal rule
# ___
#
# | Hyperlinks                     | Strikethrough | Highlight |
# | :----------------------------: | :-----------: | :-------: |
# | [link](https://www.google.com) | ~~Google~~    | `Hello`   |
